# %%
import os
import pandas as pd
from dutils.plot_chart import plotBar

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
p = 0.2
exprDir = os.path.join(".", "results", "select-{}-step=70.50.30".format(p))
results = pd.read_csv(os.path.join(exprDir, "results.csv"))
resNpy = results.to_numpy()
sel = resNpy[-1::-1, 6:8].astype(float).round(3)
labels = ["30", "50", "70"]
plotBar(labels, sel[:, 0], sel[:, 1], p)
